# %%
from tkinter import *


class Project(Frame):
    def __init__(self, root):
        super(Project, self).__init__(root)
        self.build()

    def build(self):
        self.formula = "0"
        self.lbl = Label(text=self.formula, font=("Times New Roman", 21, "bold"), bg="#808080", foreground="#FFF")
        self.lbl.place(x=11, y=50)

        knop = [
            "C", "DEL", "X^2", "/",
            "7", "8", "9", "*",
            "4", "5", "6", "+",
            "1", "2", "3", "-",
            "%", "0", ".", "="
        ]

        x = 10
        y = 140
        for bat in knop:
            cf = lambda x=bat: self.logica(x)
            Button(text=bat, bg="#FFF", font=("Helvetica", 15), command=cf).place(x=x, y=y, width=115, height=79)
            x += 117
            if x > 400:
                x = 10
                y += 81
    def logica(self, operation):
        if operation == "C":
            self.formula = ""
        elif operation == "DEL":
            self.formula = self.formula[0:-1]
        elif operation == "X^2":
            if self.formula[-1] == '+' or self.formula[-1] == '-' or self.formula[-1] == '*' or self.formula[-1] == '/': pass
            else: self.formula = str((eval(self.formula))**2)
        elif operation == "=":
            if self.formula[-1] == '+' or self.formula[-1] == '-' or self.formula[-1] == '*' or self.formula[-1] == '/': pass
            else: self.formula = str(eval(self.formula))
        elif operation == "+" or operation == "-" or operation == "/" or operation == "*":
            if self.formula[-1] == '+' or self.formula[-1] == '-' or self.formula[-1] == '*' or self.formula[-1] == '/':
                self.formula = self.formula[0:-1]
            self.formula += operation
        else:
            if self.formula == "0":
                self.formula = ""
            self.formula += operation
        self.update()

    def update(self):
        if self.formula == "":
            self.formula = "0"
        self.lbl.configure(text=self.formula)
if __name__ == '__main__':
    cal = Tk()
    cal["bg"] = "#808080"
    cal.geometry("485x540+600+200")
    cal.title("Калькулятор")
    cal.resizable(False, False)
    app = Project(cal)
    app.pack()
    cal.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/tkinter/__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "/var/folders/zz/zyxvpxvq6csfxvn_n000chrw003467/T/ipykernel_26972/3303405695.py", line 25, in <lambda>
#     cf = lambda x=bat: self.logica(x)
#                        ^^^^^^^^^^^^^^
#   File "/var/folders/zz/zyxvpxvq6csfxvn_n000chrw003467/T/ipykernel_26972/3303405695.py", line 41, in logica
#     else: self.formula = str(eval(self.formula))
#                              ^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# ZeroDivisionError: division by zero
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/tkinter/__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# Методичка №1.
#
# Задача 1. Пропавшая переменная
#
# Что нужно сделать:
#
# Найдите в программе необъявленную переменную и объявите её, присвоив ей значение ‘Кот’.
#
# client = ‘Петя’
#
# print(client)
#
# print(‘ и ’)
#
# print(pet)

# %% [markdown]
# Задача 2. Животные
#
# Что нужно сделать:
#
# Создайте две переменные с именами «Первое животное» и «Второе животное» на английском языке. Запишите в первую переменную слово «Заяц», а во вторую — «Черепаха».
# Используя эти переменные, выведите на экран текст «Заяц спит, Черепаха идёт» в одну строку.

# %% [markdown]
# Задача 3*. Калькулятор
#
# Что нужно сделать:
#
# Доделайте калькулятор. Добавьте умножение (*) и деление (/).
